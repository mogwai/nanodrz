# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from nanodrz.data import artificial_diarisation_sample, get_speakers
from nanodrz.utils import visualise_annotation, play, mel_spec

# %%
# Use the same parameters that the model was trained on to generate a sample
speakers = get_speakers()
audio, labels = artificial_diarisation_sample(speakers, sr=22050, max_secs=5, num_speakers=2, interrupt_max=.5)
print(audio.shape[-1]/16000)
reference = visualise_annotation(labels)
play(audio, 22050)
labels
# Out:
# 7.37775
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# [[0.6283340048861781, 2.970646930056246, 'A'],
#  [3.1825290162240467, 4.3638442089678104, 'A'],
#  [4.450805897406442, 5.353481634367894, 'B']]

# %%
mel = mel_spec(audio)

# %%
from typing import Optional
import matplotlib.pyplot as plt


def plot_spectrogram_to_numpy(
    spectrogram, title: Optional[str] = None, output_path: Optional[str] = None
):
    _, ax = plt.subplots(figsize=(12, 3))
    im = ax.imshow(spectrogram, aspect="auto", origin="lower", interpolation="none")
    plt.tight_layout()

    if title:
        plt.title(title)

    plt.show()

# %%
plot_spectrogram_to_numpy(mel_spec(audio)[0])
