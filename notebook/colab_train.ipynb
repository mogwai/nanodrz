# %%
# !pip install --upgrade pip install git+https://github.com/mogwai/nanodrz.git#egg=nanodrz pydantic

# %%
from nanodrz.train import main
from google.colab import userdata
k = "WANDB_API_KEY"
import os
os.environ[k] = userdata.get(k)

# %%
main("https://github.com/mogwai/nanodrz/blob/master/configs/medium_simple_no_ints_mel.yaml")
# Out:
# Resuming from /home/harry/storj/runs/nanodrz/1706300953/0006000.pt. Incrementing seed.
# Finishing last run (ID:bd78wtvd) before initializing another...
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
#  View run <strong style="color:#cdcd00">happy-butterfly-290</strong> at: <a href='https://wandb.ai/harrycblum/nano-diarization/runs/bd78wtvd' target="_blank">https://wandb.ai/harrycblum/nano-diarization/runs/bd78wtvd</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240130_184547-bd78wtvd/logs</code>
# Successfully finished last run (ID:bd78wtvd). Initializing new run:<br/>
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/home/harry/diarisation/notebook/wandb/run-20240130_184608-tw0ljc2q</code>
# ...
